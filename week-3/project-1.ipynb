# %%
csv_data=open("GIG-logistics(in).csv","rt").read()
import csv
import tkinter as tk

def submit():
    for i in csv_data.splitlines():
        valid=i.index(id_entry.get())!=-1 and i.index(name_entry.get())!=-1
        if valid:
            response_label.

root=tk.Tk()
root.title("Authentication System")
root.geometry('500x500')
tk.Label(root,text="This is a software GIG Logistics.\nYou need to enter the correct email and employee ID.\n\n\n").pack()
eid=tk.Label(root,text="Employee ID")
eid.pack()
id_entry=tk.Entry(root)
id_entry.pack()
name=tk.Label(root,text="Name")
name.pack()
name_entry=tk.Entry(root)
name_entry.pack()
submit_button=tk.Button(root,text="Submit",command=submit)
submit_button.pack()
response_label=tk.Label(root)



root.mainloop()


with csv_data as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row['Name'], row['Email'],reader.reader)
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/tkinter/__init__.py", line 2093, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "/var/folders/5b/qjbjb2fj4nq9s2671lvss5hh0000gn/T/ipykernel_50374/1128130631.py", line 6, in submit
#     for i in csv_data.splitlines():
#              ^^^^^^^^^^^^^^^^^^^
# AttributeError: '_io.TextIOWrapper' object has no attribute 'splitlines'
# Chukwuemeka Okafor c.okafor@giglogistics.com <_csv.reader object at 0x105596a40>
# Adaeze Nwosu a.nwosu@giglogistics.com <_csv.reader object at 0x105596a40>
# Tunde Adeleke t.adeleke@giglogistics.com <_csv.reader object at 0x105596a40>
# Ngozi Eze n.eze@giglogistics.com <_csv.reader object at 0x105596a40>
# Emeka Chukwu e.chukwu@giglogistics.com <_csv.reader object at 0x105596a40>
# Fatima Bello f.bello@giglogistics.com <_csv.reader object at 0x105596a40>
# Seun Adesanya s.adesanya@giglogistics.com <_csv.reader object at 0x105596a40>
# Kelechi Onyekachi k.onyekachi@giglogistics.com <_csv.reader object at 0x105596a40>
# Hauwa Musa h.musa@giglogistics.com <_csv.reader object at 0x105596a40>
# Rotimi Adeyemi r.adeyemi@giglogistics.com <_csv.reader object at 0x105596a40>
# Chioma Obi c.obi@giglogistics.com <_csv.reader object at 0x105596a40>
# Yusuf Garba y.garba@giglogistics.com <_csv.reader object at 0x105596a40>
# Blessing Okoro b.okoro@giglogistics.com <_csv.reader object at 0x105596a40>
# Taiwo Akinwale t.akinwale@giglogistics.com <_csv.reader object at 0x105596a40>
# Amina Usman a.usman@giglogistics.com <_csv.reader object at 0x105596a40>
# Ifeanyi Okonkwo i.okonkwo@giglogistics.com <_csv.reader object at 0x105596a40>
# Sade Fashola s.fashola@giglogistics.com <_csv.reader object at 0x105596a40>
# Nnamdi Okeke n.okeke@giglogistics.com <_csv.reader object at 0x105596a40>
# Maryam Abdullahi m.abdullahi@giglogistics.com <_csv.reader object at 0x105596a40>
# Oluwaseun Balogun o.balogun@giglogistics.com <_csv.reader object at 0x105596a40>
# Chidi Nwachukwu c.nwachukwu@giglogistics.com <_csv.reader object at 0x105596a40>
# Aisha Lawal a.lawal@giglogistics.com <_csv.reader object at 0x105596a40>
# Gbenga Adebisi g.adebisi@giglogistics.com <_csv.reader object at 0x105596a40>
# Nneka Oduya n.oduya@giglogistics.com <_csv.reader object at 0x105596a40>
# Ibrahim Suleiman i.suleiman@giglogistics.com <_csv.reader object at 0x105596a40>
# Tolulope Ogunwale t.ogunwale@giglogistics.com <_csv.reader object at 0x105596a40>
# Esther Aniemeka e.aniemeka@giglogistics.com <_csv.reader object at 0x105596a40>
# Biodun Ojo b.ojo@giglogistics.com <_csv.reader object at 0x105596a40>
# Rukayat Folarin r.folarin@giglogistics.com <_csv.reader object at 0x105596a40>
# Chinedu Obiora c.obiora@giglogistics.com <_csv.reader object at 0x105596a40>
# Damilola Akintola d.akintola@giglogistics.com <_csv.reader object at 0x105596a40>
# Uche Okereke u.okereke@giglogistics.com <_csv.reader object at 0x105596a40>
# Zainab Idris z.idris@giglogistics.com <_csv.reader object at 0x105596a40>
# Femi Adeyinka f.adeyinka@giglogistics.com <_csv.reader object at 0x105596a40>
# Precious Igwe p.igwe@giglogistics.com <_csv.reader object at 0x105596a40>
# Lara Oduola l.oduola@giglogistics.com <_csv.reader object at 0x105596a40>
# Tochukwu Eze t.eze@giglogistics.com <_csv.reader object at 0x105596a40>
# Hadiza Yakubu h.yakubu@giglogistics.com <_csv.reader object at 0x105596a40>
# Victor Osemeka v.osemeka@giglogistics.com <_csv.reader object at 0x105596a40>
# Chidinma Nwofor c.nwofor@giglogistics.com <_csv.reader object at 0x105596a40>
