# %%
# Integer number
num=100
print(num)
print("The data type of variable num is ",type(num))

# Float number
fnum=100
print(fnum)
print("The data type of variable num is ",type(fnum))

# Complex number
cnum= 3 + 4j
print(cnum)
print("The data type of variable num is ",type(cnum))
# Out:
# 100
# The data type of variable num is  <class 'int'>
# 100
# The data type of variable num is  <class 'int'>
# (3+4j)
# The data type of variable num is  <class 'complex'>
