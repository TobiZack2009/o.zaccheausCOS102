# %%
'''A helper function to allow us to get number inputs.'''
def input_number():
    try:
        return int(input())
    except:
        print("Enter a valid integer!")
        return input_number()


print("This program calculates the amount for: \nSimple Interest,\nCompound Interest\nAnnuity Plan")



################# SIMPLE INTEREST #################
print("--------------------SIMPLE INTEREST--------------------\n")
print("In this order, enter:\nPrincipal,\nRate,\nTime")


amount=input_number()*(1+(input_number()/100)*input_number())
print("The simple interest is ",amount,)


################# COMPOUND INTEREST #################
print("--------------------COMPOUND INTEREST--------------------\nIn this order, enter:\nNumber of Periods,\nPrincipal,\nRate,\nTime")

number_of_periods=input_number()
amount=input_number()*(1+input_number()/number_of_periods)**(input_number()*number_of_periods)
print("The compound interest is ",amount,)



################# ANNUITY PLAN #################
print("--------------------ANNUITY PLAN--------------------\nIn this order, enter:\nInitial Payment,\nRate,\nNumber of Periods,\nTime")
payment=input_number()
rate=input_number()
periods=input_number()
time=input_number()
rate_period_ratio=rate/periods
amount=payment*(((1+rate_period_ratio)**(time*number_of_periods))-1)/rate_period_ratio
print("The annuity plan amount is ",amount,)

# %% [markdown]
# # This is the flowchart for simple interest<br><br>![BEGIN.png](attachment:9296ac64-1e44-4e37-815c-25be0de63413.png)

# %% [markdown]
# # This is the flowchart for compound interest<br><br>![COMPOUND.png](attachment:a6d92dfd-d589-45d2-9717-3f90901ed983.png)

# %% [markdown]
# # This is the flowchart for annuity<br><br>![ANNUITY.png](attachment:5b8e743a-6497-4b5f-a30f-f884395156c3.png)
