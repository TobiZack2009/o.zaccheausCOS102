# %% [markdown]
# #### BEGIN
# - Go to store checkout.
# - Make a payment.
# - WHILE payment succesful
# - DO retry payment.
# - Collect the receipt.
# - Submit the receipt to the security
# - Leave the store
# #### END
#
#
# #### FLOWCHART
# ![Flowchart](attachment:356ed4ac-d0b1-476c-923c-962df083c44a.png)

# %% [markdown]
# #### My Daily Routine
# ![Routine](attachment:67d04b94-54c2-4d61-a742-a4c6fa137bbb.png)

# %% [markdown]
# #### My algorithms that accepts two names and swaps ages.
# ![BEGIN (3).png](attachment:b554e490-a2ae-4e66-bf67-8783695178e6.png)
